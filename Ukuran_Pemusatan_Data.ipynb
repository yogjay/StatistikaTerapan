# %% [markdown]
# # **Ukuran Pemusatan**
#
#
# ---

# %% [markdown]
# ## **Mean**
#
#
# *Mean atau rata-rata hitung *adalah nilai yang diperoleh dari jumlah sekelompok data dibagi dengan banyaknya data.
#
# ---
#
# > **Rata-Rata untuk Data Tunggal**
#
# > ![teks alternatif](https://myreisa.files.wordpress.com/2017/09/13.jpg)
#
# Keterangan:
#
# *   ẋ = mean
# *   n = banyaknya data
#
# **Contoh :**
#
# > Hitunglah nilai rata-rata dari nilai ujian matematika kelas 3 SMU berikut ini: 2, 4, 5, 6, 6, 7, 7, 7, 8, 9.
#
# Jawab:
# > ![teks alternatif](https://myreisa.files.wordpress.com/2017/09/gif.gif?w=1086)
#
# ---
#
# > **Rata-Rata untuk Data Berkelompok**
#
# > ![teks alternatif](https://myreisa.files.wordpress.com/2017/09/zzz.png)
#
# Keterangan:
#
# *   fi = frekuensi
# *   xi = nilai tengah
#
# *Nilai tengah adalah jumlah tepi bawah dan tepi atas di bagi 2.*
#
# **Contoh :**
#
# ![teks alternatif](https://myreisa.files.wordpress.com/2017/09/2cbb86ea6594d621ba5c4917a324d106-0.jpg?w=576&h=270)
# ![teks alternatif](https://myreisa.files.wordpress.com/2017/09/2cbb86ea6594d621ba5c4917a324d106-0-copy-2.jpg?w=317&h=154)
#
# ---

# %% [markdown]
# ## Median
#
# Median adalah nilai data yang terletak di tengah setelah data diurutkan.
#
# ---
#
# **Median untuk Data Tunggal**
#
# *   Jika banyaknya data n ganjil
#
# > ![teks alternatif](https://myreisa.files.wordpress.com/2017/09/6.jpg?w=151&h=96)
#
# *   Jika banyaknya data n genap
#
# > ![teks alternatif](https://myreisa.files.wordpress.com/2017/09/7.jpg?w=163&h=101)
#
# Keterangan :
#
#
# *   Me = Median
# *   n = jumlah data
# *   x = nilai data
#
# **Contoh :**
#
# 1.  Tentukan median dari 8,6,4,3,7,5,8,10,8,9,8,5
#
# > Data diurutkan : 3 4 5 5 6 7 8 8 8 8 9 10
#
# > N= 12 (genap) => Jadi, mediannya adlah 7,5
#
#
# 2. Sepuluh orang siswa dijadikan sampel dan dihitung tinggi badannya. Hasil pengukuran tinggi badan kesepuluh siswa tersebut adalah sebagai berikut.
# 172, 167, 180, 171, 169, 160, 175, 173, 170, 165
# Hitunglah median dari data tinggi badan siswa!
# Karena jumlah data genap, maka penghitungan median menggunakan rumus median untuk data genap. Proses penghitungannya adalah sebagai berikut.
#
# > Penghitungan median data genap
# Untuk melanjutkan penghitungan, kita harus terlebih dahulu mengetahui nilai x5 dan x6. Kedua nilai data tersebut dapat diperoleh dengan mengurutkan semua data.
#
# > Hasil pengurutan : 160, 165, 167, 169, 170, 171, 172, 173, 175, 180
#
# > Dari pengurutan tersebut diperoleh nilai x5 sama dengan 170 dan x6 sama dengan 171. Dengan demikian penghitungan median dapat dilanjutkan.![teks alternatif](https://myreisa.files.wordpress.com/2017/09/d4720-penghitunganmediandatagenap2.png?w=1086)
#
#
#
# ---
#
# ### **Median untuk data berkelompok**
#
# ![teks alternatif](https://myreisa.files.wordpress.com/2017/09/zzz1.png)
#
# Keterangan :
# * Tb  = Tepi bawah kelas median (Batas bawah – 0,5)
# * F     = Frekuensi kumulatif sebelum median
# * f      = Frekuensi
# * c     = Panjang kelas
# * n     = Jumlah frekuensi
#
# ![teks alternatif](https://myreisa.files.wordpress.com/2017/09/interval-jumlah-sekrup-caca1-copy.jpg?w=423&h=280)
# * Letak kelas median: Setengah dari seluruh data = 30, terletak pada kelas ke-3 (jumlah 9-10)
# * Tb = 9 – 0,5 = 8,5
# * c    = 2
# * n = 80, f = 24
# * f = 5 (frekuensi kelas median)
# * F = 5 + 6 = 11
#
# ![teks alternatif](https://myreisa.files.wordpress.com/2017/09/2cbb86ea6594d621ba5c4917a324d106-0-copy.jpg?w=288&h=160)
#
# ---

# %% [markdown]
# ## Modus
# Modus adalah data yang paling sering muncul atau memiliki frekuensi tertinggi.
#
#
# ---
#
# **Modus untuk data tunggal**
#
# > Modus dari data tunggal adalah data yang paling sering muncul
#
# **Contoh :**
#
# > Tentukan modus dari data berikut ! 4, 8, 7, 4, 6, 3, 6, 8, 6, 3
#
# Jawab : Data yang paling sering muncul adalah 6, maka Mo = 6
#
#
# ---
#
# **Modus untuk data berkelompok**
#
# > ![teks alternatif](https://myreisa.files.wordpress.com/2017/09/mod.png)
#
# Keterangan :
#
# *   Tb = Tepi bawah kelas modus
# *   d1 = Selisih antara frekuensi modus dengan frekuensi sebelumnya
# *   d2 = selisih antara frekuensi modus dengan frekuensi sesudahnya
# *   c = Panjang kelas
#
# **Contoh :**
# ![teks alternatif](https://myreisa.files.wordpress.com/2017/09/interval-jumlah-sekrup-caca1.jpg?w=289&h=251)
# * Kelas modul = kelas ke-4
# * Tb = 11-0.5 = 10.5
# * d1 = 7 – 5 = 2
# * d2 = 7 – 6 = 1
# * c = 2
#
# ![teks alternatif](https://myreisa.files.wordpress.com/2017/09/2cbb86ea6594d621ba5c4917a324d106-01.jpg?w=340&h=156)
